# %%
import pandas as pd

# %%
df = pd.read_csv("netflix_titles.csv")
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df[df["rating"].isna() == True]
# Out:
#      show_id     type                                              title  \
# 5989   s5990    Movie  13TH: A Conversation with Oprah Winfrey & Ava ...
# 6827   s6828  TV Show                  Gargantia on the Verdurous Planet
# 7312   s7313  TV Show                                       Little Lunch
# 7537   s7538    Movie                               My Honor Was Loyalty
#
#              director                                               cast  \
# 5989              NaN                        Oprah Winfrey, Ava DuVernay
# 6827              NaN  Kaito Ishikawa, Hisako Kanemoto, Ai Kayano, Ka...
# 7312              NaN  Flynn Curry, Olivia Deeble, Madison Lu, Oisín ...
# 7537  Alessandro Pepe  Leone Frisa, Paolo Vaccarino, Francesco Miglio...
#
#         country        date_added  release_year rating  duration  \
# 5989        NaN  January 26, 2017          2017    NaN    37 min
# 6827      Japan  December 1, 2016          2013    NaN  1 Season
# ...

# %%
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df["type"].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
df["country"].nunique()
# Out:
# 748

# %%
df["country"].unique()
# Out:
# array(['United States', 'South Africa', nan, 'India',
#        'United States, Ghana, Burkina Faso, United Kingdom, Germany, Ethiopia',
#        'United Kingdom', 'Germany, Czech Republic', 'Mexico', 'Turkey',
#        'Australia', 'United States, India, France', 'Finland',
#        'China, Canada, United States',
#        'South Africa, United States, Japan', 'Nigeria', 'Japan',
#        'Spain, United States', 'France', 'Belgium',
#        'United Kingdom, United States', 'United States, United Kingdom',
#        'France, United States', 'South Korea', 'Spain',
#        'United States, Singapore', 'United Kingdom, Australia, France',
#        'United Kingdom, Australia, France, United States',
#        'United States, Canada', 'Germany, United States',
#        'South Africa, United States', 'United States, Mexico',
#        'United States, Italy, France, Japan',
#        'United States, Italy, Romania, United Kingdom',
#        'Australia, United States', 'Argentina, Venezuela',
# ...

# %%
df.value_counts()
# Out:
# show_id  type   title                director             cast                                                                                                                                                                           country                                                 date_added          release_year  rating  duration  listed_in                                         description
# s10      Movie  The Starling         Theodore Melfi       Melissa McCarthy, Chris O'Dowd, Kevin Kline, Timothy Olyphant, Daveed Diggs, Skyler Gisondo, Laura Harrier, Rosalind Chao, Kimberly Quinn, Loretta Devine, Ravi Kapoor         United States                                           September 24, 2021  2021          PG-13   104 min   Comedies, Dramas                                  A woman adjusting to life after a loss contends with a feisty bird that's taken over her garden — and a husband who's struggling to find a way forward.     1
# ...

# %%
df[df["release_year"]>2015].head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df[df["country"]=="India"].head()
# Out:
#    show_id     type                          title    director  \
# 4       s5  TV Show                   Kota Factory         NaN
# 24     s25    Movie                          Jeans  S. Shankar
# 39     s40  TV Show                   Chhota Bheem         NaN
# 50     s51  TV Show                  Dharmakshetra         NaN
# 66     s67  TV Show  Raja Rasoi Aur Anya Kahaniyan         NaN
#
#                                                  cast country  \
# 4   Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India
# 24  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...   India
# 39  Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...   India
# 50  Kashmira Irani, Chandan Anand, Dinesh Mehta, A...   India
# 66                                                NaN   India
#
#             date_added  release_year rating   duration  \
# 4   September 24, 2021          2021  TV-MA  2 Seasons
# 24  September 21, 2021          1998  TV-14    166 min
# ...

# %%
df[df["listed_in"].str.contains("Comedies")].head()
# Out:
#    show_id     type                             title        director  \
# 4       s5  TV Show                      Kota Factory             NaN
# 9      s10    Movie                      The Starling  Theodore Melfi
# 13     s14    Movie  Confessions of an Invisible Girl   Bruno Garotti
# 15     s16  TV Show                 Dear White People             NaN
# 22     s23    Movie                   Avvai Shanmughi  K.S. Ravikumar
#
#                                                  cast        country  \
# 4   Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...  United States
# 13  Klara Castanho, Lucca Picon, Júlia Gomes, Marc...            NaN
# 15  Logan Browning, Brandon P. Bell, DeRon Horton,...  United States
# 22  Kamal Hassan, Meena, Gemini Ganesan, Heera Raj...            NaN
#
#             date_added  release_year rating   duration  \
# 4   September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# na=False helps us for reducing NaN values. If there is any nan values inside of this column this gives us error.

df[df["duration"].str.contains("Seasons",na=False)].sort_values(by="duration",ascending=False).head(10)
# Out:
#      show_id     type                          title            director  \
# 8         s9  TV Show  The Great British Baking Show     Andy Devonshire
# 1480   s1481  TV Show                     Still Game                 NaN
# 3541   s3542  TV Show                         Naruto         Hayato Date
# 6504   s6505  TV Show       Club Friday The Series 6                 NaN
# 1998   s1999  TV Show               Call the Midwife  Philippa Lowthorpe
# 1701   s1702  TV Show          American Horror Story                 NaN
# 67       s68  TV Show              Saved by the Bell                 NaN
# 5803   s5804  TV Show                 Forensic Files                 NaN
# 8442   s8443  TV Show              The Office (U.S.)                 NaN
# 3247   s3248  TV Show      Trolls: The Beat Goes On!                 NaN
#
#                                                    cast         country  \
# 8     Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...  United Kingdom
# ...

# %%
df[df["director"] == "Rajiv Chilaka"].head(
    
)
# Out:
#     show_id   type                                              title  \
# 406    s407  Movie                       Chhota Bheem - Neeli Pahaadi
# 407    s408  Movie                              Chhota Bheem & Ganesh
# 408    s409  Movie                 Chhota Bheem & Krishna: Mayanagari
# 409    s410  Movie  Chhota Bheem & Krishna: Pataliputra- City of t...
# 410    s411  Movie                 Chhota Bheem And The Broken Amulet
# 411    s412  Movie             Chhota Bheem And The Crown of Valhalla
# 412    s413  Movie               Chhota Bheem and the Incan Adventure
# 413    s414  Movie                Chhota Bheem and The ShiNobi Secret
# 414    s415  Movie                           Chhota Bheem Aur Hanuman
# 415    s416  Movie                           Chhota Bheem aur Krishna
#
#           director                                               cast country  \
# 406  Rajiv Chilaka  Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...     NaN
# ...

# %%
liste= [1,2,3,4,5]
new_list = map(lambda x: x*2,liste)
new_list

# %%
df["title_length"] = df["title"].apply(lambda x:len(x))
df[["title","title_length"]]
# Out:
#                       title  title_length
# 0      Dick Johnson Is Dead            20
# 1             Blood & Water            13
# 2                 Ganglands             9
# 3     Jailbirds New Orleans            21
# 4              Kota Factory            12
# ...                     ...           ...
# 8802                 Zodiac             6
# 8803            Zombie Dumb            11
# 8804             Zombieland            10
# 8805                   Zoom             4
# 8806                 Zubaan             6
#
# [8807 rows x 2 columns]

# %%
df["new_release_year"] = df["release_year"].apply(lambda x: x*2)
df[["new_release_year","release_year"]]
# Out:
#       new_release_year  release_year
# 0                 4040          2020
# 1                 4042          2021
# 2                 4042          2021
# 3                 4042          2021
# 4                 4042          2021
# ...                ...           ...
# 8802              4014          2007
# 8803              4036          2018
# 8804              4018          2009
# 8805              4012          2006
# 8806              4030          2015
#
# [8807 rows x 2 columns]

# %%
df["real_release_year"] = df.apply(lambda row: f"{row['new_release_year']} - {row['release_year']}",axis=1)
df[["new_release_year","release_year","real_release_year"]]
# Out:
#       new_release_year  release_year real_release_year
# 0                 4040          2020       4040 - 2020
# 1                 4042          2021       4042 - 2021
# 2                 4042          2021       4042 - 2021
# 3                 4042          2021       4042 - 2021
# 4                 4042          2021       4042 - 2021
# ...                ...           ...               ...
# 8802              4014          2007       4014 - 2007
# 8803              4036          2018       4036 - 2018
# 8804              4018          2009       4018 - 2009
# 8805              4012          2006       4012 - 2006
# 8806              4030          2015       4030 - 2015
#
# [8807 rows x 3 columns]

# %%
df.groupby(by="release_year")["title"].count().sort_values(ascending=False).head()
# Out:
# release_year
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
# Name: title, dtype: int64

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.groupby(by="country")["type"].count().sort_values(ascending=False).head()
# Out:
# country
# United States     2818
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Name: type, dtype: int64

# %%
df["date_added"] = df["date_added"].str.strip()
df["date_added"] = pd.to_datetime(df["date_added"], format='%B %d, %Y')

# %%
df["date_added_year"] = df["date_added"].dt.year

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
df.groupby("date_added_year")["title"].count().sort_values(ascending=False).head()
# Out:
# date_added_year
# 2019.0    2016
# 2020.0    1879
# 2018.0    1649
# 2021.0    1498
# 2017.0    1188
# Name: title, dtype: int64

# %%
df.groupby("director")["title"].count().sort_values(ascending=False).head(10)
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Suhas Kadav               16
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          11
# Name: title, dtype: int64

# %%
df["content_age"] = 2025- df["release_year"]
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
df["rating"].fillna(df["rating"].mode(),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   show_id          8807 non-null   object
#  1   type             8807 non-null   object
#  2   title            8807 non-null   object
#  3   director         6173 non-null   object
#  4   cast             7982 non-null   object
#  5   country          7976 non-null   object
#  6   date_added       8797 non-null   datetime64[ns]
#  7   release_year     8807 non-null   int64
#  8   rating           8803 non-null   object
#  9   duration         8804 non-null   object
#  10  listed_in        8807 non-null   object
#  11  description      8807 non-null   object
#  12  date_added_year  8797 non-null   float64
#  13  content_age      8807 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(10)
# memory usage: 963.4+ KB

# %%
df["rating"].isna().sum()
# Out:
# 4

# %%
df[df["rating"].isna() == True]
# Out:
#      show_id     type                                              title  \
# 5989   s5990    Movie  13TH: A Conversation with Oprah Winfrey & Ava ...
# 6827   s6828  TV Show                  Gargantia on the Verdurous Planet
# 7312   s7313  TV Show                                       Little Lunch
# 7537   s7538    Movie                               My Honor Was Loyalty
#
#              director                                               cast  \
# 5989              NaN                        Oprah Winfrey, Ava DuVernay
# 6827              NaN  Kaito Ishikawa, Hisako Kanemoto, Ai Kayano, Ka...
# 7312              NaN  Flynn Curry, Olivia Deeble, Madison Lu, Oisín ...
# 7537  Alessandro Pepe  Leone Frisa, Paolo Vaccarino, Francesco Miglio...
#
#         country date_added  release_year rating  duration  \
# 5989        NaN 2017-01-26          2017    NaN    37 min
# 6827      Japan 2016-12-01          2013    NaN  1 Season
# ...

# %%
df["rating"].fillna(df["rating"].mode()[0],inplace=True)

# %%
df[df["rating"].isna() == True]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
df["duration_int"] = df[df["type"] == "Movie"]["duration"]

# %%
df["duration_int"] = df["duration_int"].str.replace("min", "")

# %%
df[df["type"] == "Movie"].head(10)
# Out:
#    show_id   type                                              title  \
# 0       s1  Movie                               Dick Johnson Is Dead
# 6       s7  Movie                   My Little Pony: A New Generation
# 7       s8  Movie                                            Sankofa
# 9      s10  Movie                                       The Starling
# 12     s13  Movie                                       Je Suis Karl
# 13     s14  Movie                   Confessions of an Invisible Girl
# 16     s17  Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 18     s19  Movie                                          Intrusion
# 22     s23  Movie                                    Avvai Shanmughi
# 23     s24  Movie       Go! Go! Cory Carson: Chrissy Takes the Wheel
#
#                                          director  \
# 0                                 Kirsten Johnson
# 6                   Robert Cullen, José Luis Ucha
# 7                                    Haile Gerima
# ...

# %%
counts = df["type"].value_counts()

# %%
counts.plot(
    kind="pie",
    startangle=90,
    legend=True,
    autopct=lambda pct: f"{pct:.1f}% ({pct/100 * counts.sum():.0f})"
)
# Out:
# <Axes: ylabel='count'>

# %%
df = pd.read_csv("netflix_titles.csv")
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df[["duration_time", "duration_type"]]=df["duration"].str.split(expand=True)

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df["date_added"] = df["date_added"].str.strip()
df["date_added"] = pd.to_datetime(df["date_added"], format='%B %d, %Y')

# %%
df["quarter"] = "Q" + df["date_added"].dt.quarter.astype(str)

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
df["duration_time"] = pd.to_numeric(df["duration_time"], errors="coerce")
df[df["type"] == "Movie"].groupby("release_year")["duration_time"].mean()
# Out:
# release_year
# 1942    35.000000
# 1943    62.666667
# 1944    52.000000
# 1945    51.333333
# 1946    58.000000
#           ...
# 2017    95.535248
# 2018    96.185137
# 2019    93.466035
# 2020    92.141199
# 2021    96.444043
# Name: duration_time, Length: 73, dtype: float64

# %%
df.groupby("country")["director"].nunique().sort_values(ascending=False)
# Out:
# country
# United States                                                1560
# India                                                         645
# United Kingdom                                                195
# Canada                                                         99
# Spain                                                          95
#                                                              ...
# Canada, United States, Ireland                                  0
# Japan, Canada, United States                                    0
# Canada, United States, United Kingdom, France, Luxembourg       0
# Japan, Canada                                                   0
# Germany, Australia, France, China                               0
# Name: director, Length: 748, dtype: int64

# %%
"""
	6.	En çok içerik eklenen yıl ve ülke kombinasyonunu bul.
	7.	Her yıl için “Film” ve “TV Show” sayısını aynı grafikte göster (iki farklı renkli çizgi).
	8.	rating sütununda en sık görülen ilk 5 değeri bul ve bunların toplam içeriğe oranını hesapla (% olarak).
	9.	Belirli bir ülke (örneğin “United States”) için yıllara göre içerik trendini analiz et — artıyor mu azalıyor mu?
"""
# Out:
# '\n\t6.\tEn çok içerik eklenen yıl ve ülke kombinasyonunu bul.\n\t7.\tHer yıl için “Film” ve “TV Show” sayısını aynı grafikte göster (iki farklı renkli çizgi).\n\t8.\trating sütununda en sık görülen ilk 5 değeri bul ve bunların toplam içeriğe oranını hesapla (% olarak).\n\t9.\tBelirli bir ülke (örneğin “United States”) için yıllara göre içerik trendini analiz et — artıyor mu azalıyor mu?\n'

# %%
df.groupby(["release_year","country"]).size().sort_values(ascending=False)
# Out:
# release_year  country
# 2018          United States                                        356
# 2017          United States                                        352
# 2019          United States                                        351
# 2020          United States                                        336
# 2016          United States                                        263
#                                                                   ...
# 2005          Germany, United States, Canada                         1
# 2015          Vietnam                                                1
#               United States, Uruguay                                 1
#               United States, United Kingdom, Spain, South Korea      1
# 2021          Vietnam                                                1
# Length: 1754, dtype: int64

# %%
df.groupby("release_year")["type"].size()
# Out:
# release_year
# 1925       1
# 1942       2
# 1943       3
# 1944       3
# 1945       4
#         ...
# 2017    1032
# 2018    1147
# 2019    1030
# 2020     953
# 2021     592
# Name: type, Length: 74, dtype: int64
